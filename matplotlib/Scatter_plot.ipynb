# %% [markdown]
# <a href="https://colab.research.google.com/github/JP109/ML-Basics/blob/main/matplotlib/Scatter_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import matplotlib and allow plots to be shown in Jupyter Notebook
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd

# %% [markdown]
# # **1. Scatter plot with plt.plot**
# Like line plots, plt.plot can also be used to create scatter plots

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)

plt.plot(x, y, 'o', color='black')

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
  plt.plot(rng.rand(5), rng.rand(5), marker, label='marker= {}'.format(marker))
plt.legend(numpoints = 1)
plt.xlim(0, 1.8);

# %% [markdown]
# These character codes can be used together with line and color codes to plot points along with a line connecting them:

# %%
plt.plot(x, y, '-xk')

# %% [markdown]
# Additional plt.plot keyword arguments: (Refer plt.plot documentation for full list)

# %%
plt.plot(x, y, '-p', color='gray', markersize=15, markerfacecolor='white', markeredgecolor='gray', markeredgewidth=2)
plt.ylim(-1.2, 1.2)
# Out:
# (-1.2, 1.2)

# %% [markdown]
# ## **2. Scatter plots with plt.scatter**
# The primary difference of plt.scatter from plt.plot is that it can be used to create scatter plots where the properties of each individual point (size, face color, edge color, etc.) can be individually controlled or mapped to data.
#
#
# Although plt.scatter is more powerful than plt.plot, **as datasets get larger than a few thousand points, plt.plot can be noticeably more efficient than plt.scatter.** The reason is that plt.scatter has the capability to render a different size and/or color for each point, so the renderer must do the extra work of constructing each point individually. In plt.plot, on the other hand, the points are always essentially clones of each other, so the work of determining the appearance of the points is done only once for the entire set of data. For large datasets, the difference between these two can lead to vastly different performance, and for this reason, plt.plot should be preferred over plt.scatter for large datasets.

# %%
plt.scatter(x, y, marker='o')

# %%
rng = np.random.RandomState(0)
x = rng.rand(100)
y = rng.rand(100)
colors = rng.rand(100)
sizes = 1000*rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap='viridis')
plt.colorbar()

# %% [markdown]
# Notice that the color argument is automatically mapped to a color scale (shown here by the colorbar() command), and that the size argument is given in pixels. In this way, the color and size of points can be used to convey information in the visualization, in order to visualize multidimensional data.

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=0.2, s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
# Out:
# Text(0, 0.5, 'sepal width (cm)')
